# %% [markdown]
# ## Extra Visualizations: Year by Year Visualizations
#
# I wanted to separate the scatterplot I made of yearly pace and distance so that the scatterplots for each individual year could be seen. In these extra visualizations, I simply repurposed the code I used to create the main graph.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dolwick_project import splitdate
from dolwick_project import test_splitdate

# %%
e = pd.read_csv("clean.csv")

# %%
eymd = splitdate.splitdate(e, e['Date'])
pd.options.display.max_rows=20
print(eymd)
#making sure splitdate works properly
test_splitdate.tsd()
# Out:
#             Date  Mileage time_corr   pace_min  year month day
# 0     2009-01-05     1.00       NaN        NaN  2009    01  05
# 1     2009-04-25     3.10   0:29:38   9.559140  2009    04  25
# 2     2009-11-21     3.10   0:22:51   7.370968  2009    11  21
# 3     2010-01-04     1.30   0:17:00  13.076923  2010    01  04
# 4     2010-01-05     2.60   0:28:00  10.769231  2010    01  05
# ...          ...      ...       ...        ...   ...   ...  ..
# 3337  2024-08-09     1.73    0:9:34   5.529865  2024    08  09
# 3338  2024-08-09     2.87       NaN        NaN  2024    08  09
# 3339  2024-08-12     6.21   0:48:14   7.767042  2024    08  12
# 3340  2024-08-13     6.27   0:44:32   7.102605  2024    08  13
# 3341  2024-08-14     8.77       NaN        NaN  2024    08  14
#
# [3342 rows x 7 columns]

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600'}

fig2009 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2009 = fig2009.gca()
ax2009.scatter(eymd['Mileage'][(eymd['year'] == '2009')],eymd['pace_min'][(eymd['year'] == '2009')],c='#000000',alpha=0.3)
ax2009.set_xlabel('Distance (mi)', fontsize=13)
ax2009.set_ylabel('Pace (min/mi)', fontsize=13)
ax2009.set_title('Pace and Distance of Each Run in 2009', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2009')

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600'}

fig2010 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2010 = fig2010.gca()
ax2010.scatter(eymd['Mileage'][(eymd['year'] == '2010')],eymd['pace_min'][(eymd['year'] == '2010')],c='#450842',alpha=0.3)
ax2010.set_xlabel('Distance (mi)', fontsize=13)
ax2010.set_ylabel('Pace (min/mi)', fontsize=13)
ax2010.set_title('Pace and Distance of Each Run in 2010', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2010')

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600'}

fig2011 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2011 = fig2011.gca()
ax2011.scatter(eymd['Mileage'][(eymd['year'] == '2011')],eymd['pace_min'][(eymd['year'] == '2011')],c='#1B0951',alpha=0.3)
ax2011.set_xlabel('Distance (mi)', fontsize=13)
ax2011.set_ylabel('Pace (min/mi)', fontsize=13)
ax2011.set_title('Pace and Distance of Each Run in 2011', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2011')

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600'}

fig2012 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2012 = fig2012.gca()
ax2012.scatter(eymd['Mileage'][(eymd['year'] == '2012')],eymd['pace_min'][(eymd['year'] == '2012')],c='#1620CD',alpha=0.3)
ax2012.set_xlabel('Distance (mi)', fontsize=13)
ax2012.set_ylabel('Pace (min/mi)', fontsize=13)
ax2012.set_title('Pace and Distance of Each Run in 2012', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2012')

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600'}

fig2013 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2013 = fig2013.gca()
ax2013.scatter(eymd['Mileage'][(eymd['year'] == '2013')],eymd['pace_min'][(eymd['year'] == '2013')],c='#3AA6FF',alpha=0.3)
ax2013.set_xlabel('Distance (mi)', fontsize=13)
ax2013.set_ylabel('Pace (min/mi)', fontsize=13)
ax2013.set_title('Pace and Distance of Each Run in 2013', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2013')

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600'}

fig2014 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2014 = fig2014.gca()
ax2014.scatter(eymd['Mileage'][(eymd['year'] == '2014')],eymd['pace_min'][(eymd['year'] == '2014')],c='#3AFFDE',alpha=0.3)
ax2014.set_xlabel('Distance (mi)', fontsize=13)
ax2014.set_ylabel('Pace (min/mi)', fontsize=13)
ax2014.set_title('Pace and Distance of Each Run in 2014', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2014')

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600'}

fig2015 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2015 = fig2015.gca()
ax2015.scatter(eymd['Mileage'][(eymd['year'] == '2015')],eymd['pace_min'][(eymd['year'] == '2015')],c='#3AFF51',alpha=0.3)
ax2015.set_xlabel('Distance (mi)', fontsize=13)
ax2015.set_ylabel('Pace (min/mi)', fontsize=13)
ax2015.set_title('Pace and Distance of Each Run in 2015', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2015')

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600'}

fig2016 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2016 = fig2016.gca()
ax2016.scatter(eymd['Mileage'][(eymd['year'] == '2016')],eymd['pace_min'][(eymd['year'] == '2016')],c='#D0FF00',alpha=0.3)
ax2016.set_xlabel('Distance (mi)', fontsize=13)
ax2016.set_ylabel('Pace (min/mi)', fontsize=13)
ax2016.set_title('Pace and Distance of Each Run in 2016', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2016')

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600'}

fig2017 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2017 = fig2017.gca()
ax2017.scatter(eymd['Mileage'][(eymd['year'] == '2017')],eymd['pace_min'][(eymd['year'] == '2017')],c='#FFC600',alpha=0.3)
ax2017.set_xlabel('Distance (mi)', fontsize=13)
ax2017.set_ylabel('Pace (min/mi)', fontsize=13)
ax2017.set_title('Pace and Distance of Each Run in 2017', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2017')

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600'}

fig2018 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2018 = fig2018.gca()
ax2018.scatter(eymd['Mileage'][(eymd['year'] == '2018')],eymd['pace_min'][(eymd['year'] == '2018')],c='#FF8600',alpha=0.3)
ax2018.set_xlabel('Distance (mi)', fontsize=13)
ax2018.set_ylabel('Pace (min/mi)', fontsize=13)
ax2018.set_title('Pace and Distance of Each Run in 2018', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2018')

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600'}

fig2019 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2019 = fig2019.gca()
ax2019.scatter(eymd['Mileage'][(eymd['year'] == '2019')],eymd['pace_min'][(eymd['year'] == '2019')],c='#FF3600',alpha=0.3)
ax2019.set_xlabel('Distance (mi)', fontsize=13)
ax2019.set_ylabel('Pace (min/mi)', fontsize=13)
ax2019.set_title('Pace and Distance of Each Run in 2019', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2019')

# %%
# col_dict = {'2009':'#000000', '2010':'#450842', '2011':'#1B0951', '2012':'#1620CD' , 
            #'2013':'#3AA6FF' , '2014':'#3AFFDE' , '2015':'#3AFF51' , '2016':'#D0FF00',
            #'2017':'#FFC600', '2018':'#FF8600', '2019':'#FF3600', '2020':'#FF00C6'}

fig2020 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2020 = fig2020.gca()
ax2020.scatter(eymd['Mileage'][(eymd['year'] == '2020')],eymd['pace_min'][(eymd['year'] == '2020')],c='#FF00C6',alpha=0.3)
ax2020.set_xlabel('Distance (mi)', fontsize=13)
ax2020.set_ylabel('Pace (min/mi)', fontsize=13)
ax2020.set_title('Pace and Distance of Each Run in 2020', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2020')

# %%
fig2021 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2021 = fig2021.gca()
ax2021.scatter(eymd['Mileage'][(eymd['year'] == '2021')],eymd['pace_min'][(eymd['year'] == '2021')],c='#7700FF',alpha=0.3)
ax2021.set_xlabel('Distance (mi)', fontsize=13)
ax2021.set_ylabel('Pace (min/mi)', fontsize=13)
ax2021.set_title('Pace and Distance of Each Run in 2021', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2021')

# %%
fig2022 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2022 = fig2022.gca()
ax2022.scatter(eymd['Mileage'][(eymd['year'] == '2022')],eymd['pace_min'][(eymd['year'] == '2022')],c='#770099',alpha=0.3)
ax2022.set_xlabel('Distance (mi)', fontsize=13)
ax2022.set_ylabel('Pace (min/mi)', fontsize=13)
ax2022.set_title('Pace and Distance of Each Run in 2022', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2022')

# %%
fig2023 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2023 = fig2023.gca()
ax2023.scatter(eymd['Mileage'][(eymd['year'] == '2023')],eymd['pace_min'][(eymd['year'] == '2023')],c='#550055',alpha=0.3)
ax2023.set_xlabel('Distance (mi)', fontsize=13)
ax2023.set_ylabel('Pace (min/mi)', fontsize=13)
ax2023.set_title('Pace and Distance of Each Run in 2023', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2023')

# %%
fig2024 = plt.figure(figsize=(12,10),dpi=75)
plt.xticks(np.arange(0, max(e['Mileage'])+1, 1.0))
plt.xlim(0,max(e['Mileage'])+1)
plt.ylim(3.5, 12)
ax2024 = fig2024.gca()
ax2024.scatter(eymd['Mileage'][(eymd['year'] == '2024')],eymd['pace_min'][(eymd['year'] == '2024')],c='#550055',alpha=0.3)
ax2024.set_xlabel('Distance (mi)', fontsize=13)
ax2024.set_ylabel('Pace (min/mi)', fontsize=13)
ax2024.set_title('Pace and Distance of Each Run in 2024', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pace and Distance of Each Run in 2024')
